# %%
import os, findspark
os.environ["JAVA_HOME"] = r"C:\java"
os.environ["HADOOP_HOME"] = r"C:\hadoop"   # opcional, por winutils
findspark.init(r"C:\spark")

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()

df_listings = spark.read.parquet("C:/airbnb/bronze/listings")
df_listings.show(5)
# Out:
# +-----+--------------------+-------+---------------+-------------------+-------------+---------+---------+---------------+-------+--------------+-----------------+-----------+-----------------+------------------------------+----------------+---------------------+-------+-------+------+--------+-------------+
# |   id|                name|host_id|      host_name|neighbourhood_group|neighbourhood| latitude|longitude|      room_type|  price|minimum_nights|number_of_reviews|last_review|reviews_per_month|calculated_host_listings_count|availability_365|number_of_reviews_ltm|license|country|region|    city|snapshot_date|
# +-----+--------------------+-------+---------------+-------------------+-------------+---------+---------+---------------+-------+--------------+-----------------+-----------+-----------------+------------------------------+----------------+---------------------+-------+-------+------+--------+-------------+
# ...

# %%
import sys
import numpy as np

print("Python ejecutable:", sys.executable)
print("NumPy version:", np.__version__)
# Out:
# Python ejecutable: d:\UPAO\VIII\Big Data\Proyecto\venv\Scripts\python.exe
# NumPy version: 2.2.6

# %%
import sys
import numpy as np

print("Python ejecutable:", sys.executable)
print("NumPy version:", np.__version__)
# Out:
# Python ejecutable: d:\UPAO\VIII\Big Data\Proyecto\venv\Scripts\python.exe
# NumPy version: 2.2.6

# %%
df_gold = spark.read.parquet("C:/airbnb/gold/predicciones")
df_gold.show(5)
# Out:
# +-----+-------------+---------------+---------+---------+------------------+--------------+--------------+----------------+-----------------+-----------------+------------------------------+--------------------+------------------+
# |   id|neighbourhood|      room_type| latitude|longitude|         price_usd|demand_cluster|minimum_nights|availability_365|number_of_reviews|reviews_per_month|calculated_host_listings_count|      occupancy_rate|        prediction|
# +-----+-------------+---------------+---------+---------+------------------+--------------+--------------+----------------+-----------------+-----------------+------------------------------+--------------------+------------------+
# |49392|  Providencia|   Private room|-33.43277|-70.59892|56.365591397849464|             0|             3|             178|                0|              0.0|                             1|  0.5123287671232877|61.040061125090524|
# ...
